# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('Jobdemandbyindustry.xlsx')

# %%
df
# Out:
#     Unnamed: 0  \
# 0   1984-11-01
# 1   1985-02-01
# 2   1985-05-01
# 3   1985-08-01
# 4   1985-11-01
# ..         ...
# 137 2019-02-01
# 138 2019-05-01
# 139 2019-08-01
# 140 2019-11-01
# 141 2020-02-01
#
#      Australia ;  Agriculture, Forestry and Fishing ;  Employed total ;  \
# 0                                           410.719753
# 1                                           404.842338
# 2                                           394.461506
# 3                                           413.675791
# 4                                           433.581180
# ..                                                 ...
# 137                                         346.213207
# 138                                         334.411332
# 139                                         319.032738
# 140                                         318.964108
# 141                                         337.223927
#
#      Australia ;  Agriculture, Forestry and Fishing ;  > Employed full-time ;  \
# ...

# %%
df = df[df.columns[~df.columns.str.endswith('Employed full-time ;')]]

# %%
df = df[df.columns[~df.columns.str.endswith('Employed part-time ;')]]

# %%
df.columns = df.columns.str.replace('Australia ;', '')

# %%
df.columns = df.columns.str.replace('>', '')

# %%
df.columns = df.columns.str.lstrip()

# %%
z=df.loc[:, 'New South Wales ;  Agriculture, Forestry and Fishing':]

# %%
df.drop(df.loc[:,'New South Wales ;  Agriculture, Forestry and Fishing':], axis=1,inplace=True)

# %%
df.to_excel('jobbysalarycleaned.xlsx', 'w')
